# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
def prepare_data(data, is_train=True, medians=None, sector_aggregations=None):
    """
    Function to prepare and transform the financial data for machine learning.
    
    Parameters:
    data (pd.DataFrame): The input data to be prepared.
    is_train (bool): Flag to indicate if the data is training data. Default is True.
    medians (pd.Series): Precomputed median values for the columns. Default is None.
    sector_aggregations (pd.DataFrame): Precomputed sector-based aggregations. Default is None.
    
    Returns:
    pd.DataFrame: The prepared and transformed data.
    pd.Series: The median values used for filling missing values (only when is_train=True).
    pd.DataFrame: The sector-based aggregations (only when is_train=True).
    """
    
    data.replace("NA", -999, inplace=True)
    
    data.replace("", float("nan"), inplace=True)
    
    if is_train:
        medians = data.median()
    
    data.fillna(medians, inplace=True)
    
    data['Debt_to_Equity'] = data['Debt - Total to EBITDA, TTM'] / data['Net Debt to Total Equity']
    data['Current_Ratio_Diff'] = data['Current Ratio'] - data['Quick Ratio']
    
    # feature interactions
    data['ROA_ROE_interaction'] = data['Return on Average Total Assets - %, TTM'] * data['Return on Average Common Equity - %, TTM']
    data['Debt_to_Equity_interaction'] = data['Debt - Total to EBITDA, TTM'] * data['Net Debt to Total Equity']
    data['EBITDA_NetMargin_interaction'] = data['EBITDA Margin - %, TTM'] * data['Net Margin - %, TTM']
    data['PE_DividendYield_interaction'] = data['Price to EBITDA per Share, TTM'] * data['Dividend Yield - Common - Net - Issue - %, TTM']
    data['Operating_GrossMargin_interaction'] = data['Operating Margin - %, TTM'] * data['Gross Profit Margin - %, TTM']
    
    # log transform for skewed features
    skewed_features = ['Return on Average Total Assets - %, TTM', 'Return on Average Common Equity - %, TTM']
    for feature in skewed_features:
        data[f'{feature}_log'] = np.log1p(data[feature])
    
    # sector-based aggregations
    if is_train:
        sector_aggregations = data.groupby('Industry sector').agg({
            'Return on Average Total Assets - %, TTM': ['mean', 'std'],
            'Return on Average Common Equity - %, TTM': ['mean', 'std'],
        }).reset_index()
        
        sector_aggregations.columns = ['_'.join(col).strip() for col in sector_aggregations.columns.values]
        sector_aggregations.rename(columns={'Industry sector_':'Industry sector'}, inplace=True)
    
    # Merge the sector aggregations back to the original data
    data = data.merge(sector_aggregations, on='Industry sector', how='left')
    data.loc[:,"Industry sector"] = data["Industry sector"].astype("category")
    
    return data, medians, sector_aggregations




def custom_loss_function(y_true, y_pred):
    cost_matrix = np.array([
        [0, 1, 2],
        [1, 0, 1],
        [2, 1, 0]
    ])
    conf_matrix = confusion_matrix(y_true, y_pred)
    error = np.sum(conf_matrix * cost_matrix) / len(y_true)
    return error

custom_metric = {
    'name': 'custom_loss', 
    'score_func': custom_loss_function, 
    'greater_is_better': False
}

# %%
raw = pd.read_csv("data/training_data.csv", sep=";", decimal=",")
raw_test = pd.read_csv("data/test_data_no_target.csv", sep=";", decimal=",")

col_dictionary = pd.read_csv("data/column_names_dictionary.csv", sep=";")
name_mapping = col_dictionary.set_index('CODE')['INDICATOR NAME'].to_dict()

raw = raw.rename(columns=name_mapping)
raw_test = raw_test.rename(columns=name_mapping)
data, medians, sector_aggregations = prepare_data(raw, is_train=True)
test_data_prepared, _, _ = prepare_data(raw_test, is_train=False, medians=medians, sector_aggregations=sector_aggregations)

X_train = data.drop(columns=['Class', 'Perform'])
y_train = data['Class']
class_mapping = {-1: 0, 0: 1, 1: 2}
y_train_mapped = y_train.map(class_mapping)

X_test = test_data_prepared.drop(columns=['Class', 'Perform'], errors='ignore')

# %%
X_train.info(max_cols=140)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 0 to 7999
# Data columns (total 130 columns):
#  #    Column                                                                                Non-Null Count  Dtype
# ---   ------                                                                                --------------  -----
#  0    Industry sector                                                                       8000 non-null   category
#  1    Return on Average Total Assets - %, TTM                                               8000 non-null   float64
#  2    Return on Average Common Equity - %, TTM                                              8000 non-null   float64
#  3    EBITDA Percentage of Common Equity, TTM                                               8000 non-null   float64
#  4    EBITDA Percentage of Total Fixed Assets - Net, TTM                                    8000 non-null   float64
#  5    Excess Cash Margin - %                                                                8000 non-null   float64
#  6    Free Cash Flow Percentage of Total Revenue, TTM                                       8000 non-null   float64
#  7    Cash Flow from Operations Pct of Total Revenue, TTM                                   8000 non-null   float64
#  8    Cash Flow from Operations Pct of Common Equity, TTM                                   8000 non-null   float64
#  9    Cash Flow from Operations to Total Assets, TTM                                        8000 non-null   float64
#  10   Reinvestment Rate - %, TTM                                                            8000 non-null   float64
#  11   Return on Capital Employed - %, TTM                                                   8000 non-null   float64
#  12   Working Capital Percentage of Total Revenue, YoY Diff, TTM                            8000 non-null   float64
#  13   Dividend Payout Ratio - %, TTM                                                        8000 non-null   float64
#  14   Payables Turnover, TTM                                                                8000 non-null   float64
#  15   Cash Flow from Operations Ratio, TTM                                                  8000 non-null   float64
#  16   Cash Percentage of Total Revenue, TTM                                                 8000 non-null   float64
#  17   Debt - Total to EBITDA, TTM                                                           8000 non-null   float64
#  18   FCF Net of Dividends Pct of Debt, Pref Eq & Min Intr, TTM                             8000 non-null   float64
#  19   Net Debt to EBITDA, TTM                                                               8000 non-null   float64
#  20   Solvency Ratio - %, TTM                                                               8000 non-null   float64
#  21   Inventory Turnover, TTM                                                               8000 non-null   float64
#  22   Net Operating Asset Turnover, TTM                                                     8000 non-null   float64
#  23   Sales to Receivables, TTM                                                             8000 non-null   float64
#  24   Accounts Receivable Turnover, TTM                                                     8000 non-null   float64
#  25   Asset Turnover, TTM                                                                   8000 non-null   float64
#  26   Average Net Trade Cycle Days, TTM                                                     8000 non-null   float64
#  27   Current Asset Turnover, TTM                                                           8000 non-null   float64
#  28   Fixed Asset Turnover, TTM                                                             8000 non-null   float64
#  29   Enterprise Value to EBIT, TTM                                                         8000 non-null   float64
#  30   Enterprise Value to EBITDA, TTM                                                       8000 non-null   float64
#  31   Enterprise Value to Total Revenue, TTM                                                8000 non-null   float64
#  32   Gross Profit Margin - %, TTM                                                          8000 non-null   float64
#  33   Operating Margin - %, TTM                                                             8000 non-null   float64
#  34   EBIT Margin - %, TTM                                                                  8000 non-null   float64
#  35   EBITDA Margin - %, TTM                                                                8000 non-null   float64
#  36   Net Margin - %, TTM                                                                   8000 non-null   float64
#  37   Cash Flow Margin - %, TTM                                                             8000 non-null   float64
#  38   Price to Cash Flow per Share, TTM                                                     8000 non-null   float64
#  39   Price to EBITDA per Share, TTM                                                        8000 non-null   float64
#  40   Price to Total Revenue per Share, TTM                                                 8000 non-null   float64
#  41   EPS Basic excl Exord, Common - Total to Price - %, TTM                                8000 non-null   float64
#  42   EPS Basic incl Exord, Common - Total to Price - %, TTM                                8000 non-null   float64
#  43   Dividend Yield - Common - Net - Issue - %, TTM                                        8000 non-null   float64
#  44   PE Growth Ratio, TTM                                                                  8000 non-null   float64
#  45   Total Current Assets Percentage of Total Assets                                       8000 non-null   float64
#  46   Total Current Liabilities Percentage of Total Assets                                  8000 non-null   float64
#  47   Cash & Cash Equivalents to Total Assets                                               8000 non-null   float64
#  48   Inventories Percentage of Total Assets                                                8000 non-null   float64
#  49   Current Ratio                                                                         8000 non-null   float64
#  50   Quick Ratio                                                                           8000 non-null   float64
#  51   Working Capital to Total Assets                                                       8000 non-null   float64
#  52   Cash Ratio                                                                            8000 non-null   float64
#  53   Net Debt to Total Equity                                                              8000 non-null   float64
#  54   Total Liabilities Percentage of Total Assets                                          8000 non-null   float64
#  55   Long Term Debt Percentage of Total Assets                                             8000 non-null   float64
#  56   Book Value Percentage of Market Capitalization                                        8000 non-null   float64
#  57   Cash Flow from Operations Pct of Capital Expenditures                                 8000 non-null   float64
#  58   Price to Cash Flow from Operations per Share, TTM                                     8000 non-null   float64
#  59   1-year Absolute Change of Return on Average Total Assets - %, TTM                     8000 non-null   float64
#  60   1-year Absolute Change of Return on Average Common Equity - %, TTM                    8000 non-null   float64
#  61   1-year Absolute Change of EBITDA Percentage of Common Equity, TTM                     8000 non-null   float64
#  62   1-year Absolute Change of EBITDA Percentage of Total Fixed Assets - Net, TTM          8000 non-null   float64
#  63   1-year Absolute Change of Excess Cash Margin - %                                      8000 non-null   float64
#  64   1-year Absolute Change of Free Cash Flow Percentage of Total Revenue, TTM             8000 non-null   float64
#  65   1-year Absolute Change of Cash Flow from Operations Pct of Total Revenue, TTM         8000 non-null   float64
#  66   1-year Absolute Change of Cash Flow from Operations Pct of Common Equity, TTM         8000 non-null   float64
#  67   1-year Absolute Change of Cash Flow from Operations to Total Assets, TTM              8000 non-null   float64
#  68   1-year Absolute Change of Reinvestment Rate - %, TTM                                  8000 non-null   float64
#  69   1-year Absolute Change of Return on Capital Employed - %, TTM                         8000 non-null   float64
#  70   1-year Absolute Change of Working Capital Percentage of Total Revenue, YoY Diff, TTM  8000 non-null   float64
#  71   1-year Absolute Change of Dividend Payout Ratio - %, TTM                              8000 non-null   float64
#  72   1-year Absolute Change of Payables Turnover, TTM                                      8000 non-null   float64
#  73   1-year Absolute Change of Cash Flow from Operations Ratio, TTM                        8000 non-null   float64
#  74   1-year Absolute Change of Cash Percentage of Total Revenue, TTM                       8000 non-null   float64
#  75   1-year Absolute Change of Debt - Total to EBITDA, TTM                                 8000 non-null   float64
#  76   1-year Absolute Change of FCF Net of Dividends Pct of Debt, Pref Eq & Min Intr, TTM   8000 non-null   float64
#  77   1-year Absolute Change of Net Debt to EBITDA, TTM                                     8000 non-null   float64
#  78   1-year Absolute Change of Solvency Ratio - %, TTM                                     8000 non-null   float64
#  79   1-year Absolute Change of Inventory Turnover, TTM                                     8000 non-null   float64
#  80   1-year Absolute Change of Net Operating Asset Turnover, TTM                           8000 non-null   float64
#  81   1-year Absolute Change of Sales to Receivables, TTM                                   8000 non-null   float64
#  82   1-year Absolute Change of Accounts Receivable Turnover, TTM                           8000 non-null   float64
#  83   1-year Absolute Change of Asset Turnover, TTM                                         8000 non-null   float64
#  84   1-year Absolute Change of Average Net Trade Cycle Days, TTM                           8000 non-null   float64
#  85   1-year Absolute Change of Current Asset Turnover, TTM                                 8000 non-null   float64
#  86   1-year Absolute Change of Fixed Asset Turnover, TTM                                   8000 non-null   float64
#  87   1-year Absolute Change of Enterprise Value to EBIT, TTM                               8000 non-null   float64
#  88   1-year Absolute Change of Enterprise Value to EBITDA, TTM                             8000 non-null   float64
#  89   1-year Absolute Change of Enterprise Value to Total Revenue, TTM                      8000 non-null   float64
#  90   1-year Absolute Change of Gross Profit Margin - %, TTM                                8000 non-null   float64
#  91   1-year Absolute Change of Operating Margin - %, TTM                                   8000 non-null   float64
#  92   1-year Absolute Change of EBIT Margin - %, TTM                                        8000 non-null   float64
#  93   1-year Absolute Change of EBITDA Margin - %, TTM                                      8000 non-null   float64
#  94   1-year Absolute Change of Net Margin - %, TTM                                         8000 non-null   float64
#  95   1-year Absolute Change of Cash Flow Margin - %, TTM                                   8000 non-null   float64
#  96   1-year Absolute Change of Price to Cash Flow per Share, TTM                           8000 non-null   float64
#  97   1-year Absolute Change of Price to EBITDA per Share, TTM                              8000 non-null   float64
#  98   1-year Absolute Change of Price to Total Revenue per Share, TTM                       8000 non-null   float64
#  99   1-year Absolute Change of EPS Basic excl Exord, Common - Total to Price - %, TTM      8000 non-null   float64
#  100  1-year Absolute Change of EPS Basic incl Exord, Common - Total to Price - %, TTM      8000 non-null   float64
#  101  1-year Absolute Change of Dividend Yield - Common - Net - Issue - %, TTM              8000 non-null   float64
#  102  1-year Absolute Change of PE Growth Ratio, TTM                                        8000 non-null   float64
#  103  1-year Absolute Change of Total Current Assets Percentage of Total Assets             8000 non-null   float64
#  104  1-year Absolute Change of Total Current Liabilities Percentage of Total Assets        8000 non-null   float64
#  105  1-year Absolute Change of Cash & Cash Equivalents to Total Assets                     8000 non-null   float64
#  106  1-year Absolute Change of Inventories Percentage of Total Assets                      8000 non-null   float64
#  107  1-year Absolute Change of Current Ratio                                               8000 non-null   float64
#  108  1-year Absolute Change of Quick Ratio                                                 8000 non-null   float64
#  109  1-year Absolute Change of Working Capital to Total Assets                             8000 non-null   float64
#  110  1-year Absolute Change of Cash Ratio                                                  8000 non-null   float64
#  111  1-year Absolute Change of Net Debt to Total Equity                                    8000 non-null   float64
#  112  1-year Absolute Change of Total Liabilities Percentage of Total Assets                8000 non-null   float64
#  113  1-year Absolute Change of Long Term Debt Percentage of Total Assets                   8000 non-null   float64
#  114  1-year Absolute Change of Book Value Percentage of Market Capitalization              8000 non-null   float64
#  115  1-year Absolute Change of Cash Flow from Operations Pct of Capital Expenditures       8000 non-null   float64
#  116  1-year Absolute Change of Price to Cash Flow from Operations per Share, TTM           8000 non-null   float64
#  117  Debt_to_Equity                                                                        8000 non-null   float64
#  118  Current_Ratio_Diff                                                                    8000 non-null   float64
#  119  ROA_ROE_interaction                                                                   8000 non-null   float64
#  120  Debt_to_Equity_interaction                                                            8000 non-null   float64
#  121  EBITDA_NetMargin_interaction                                                          8000 non-null   float64
#  122  PE_DividendYield_interaction                                                          8000 non-null   float64
#  123  Operating_GrossMargin_interaction                                                     8000 non-null   float64
#  124  Return on Average Total Assets - %, TTM_log                                           7786 non-null   float64
#  125  Return on Average Common Equity - %, TTM_log                                          8000 non-null   float64
#  126  Return on Average Total Assets - %, TTM_mean                                          8000 non-null   float64
#  127  Return on Average Total Assets - %, TTM_std                                           8000 non-null   float64
#  128  Return on Average Common Equity - %, TTM_mean                                         8000 non-null   float64
#  129  Return on Average Common Equity - %, TTM_std                                          8000 non-null   float64
# dtypes: category(1), float64(129)
# memory usage: 7.9 MB

# %%
from utils import CustomCMLoss

def custom_objective(y_true, y_pred):
    # Convert the predictions to probabilities
    loss = CustomCMLoss()
    grad, hess = loss(y_true, y_pred)
    
    return grad, hess

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score


# Create a scorer using the custom metric
custom_scorer = make_scorer(custom_loss_function)

xgb_model = XGBClassifier( enable_categorical=True, objective=custom_objective)
# Perform cross-validation
cv_scores = cross_val_score(xgb_model, X_train, y_train_mapped, cv=5, scoring=custom_scorer)

# Print cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score:", np.mean(cv_scores))
# Out:
# Cross-validation scores: [1.083125 1.084375 1.084375 1.084375 1.08375 ]
# Mean cross-validation score: 1.084

# %%
cv_scores, np.m
# Out:
# array([0.911875, 0.888125, 0.899375, 0.8775  , 0.8875  ])

# %%
xgb_model.fit(X_train, y_train_mapped)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = xgb_model.predict(X_train)
